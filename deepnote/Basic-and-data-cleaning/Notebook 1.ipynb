# %%
import pandas as pd
import numpy as np

# %%
time_series = pd.date_range('1/01/2020', periods=10)

# %%
df = pd.DataFrame(np.random.randn(10,5),index=time_series,columns=['col1','col2','col3','col4','col5'])
df
# Out:
#                 col1      col2      col3      col4      col5
# 2020-01-01  0.717763 -0.063574 -0.573939  0.371611  0.799530
# 2020-01-02 -0.943662 -0.410812 -0.399872  0.567276  2.064047
# 2020-01-03  1.427493  1.391120 -0.330402  0.990232  1.304601
# 2020-01-04 -1.387690 -1.103715  0.947479  1.173306  0.631514
# 2020-01-05  0.138568  0.448661 -0.979584 -0.104487  0.349249
# 2020-01-06 -0.273605  0.237992  1.006326 -1.726415 -0.164366
# 2020-01-07 -1.172133 -1.040343  0.438945  0.895940 -1.039045
# 2020-01-08 -0.781139 -1.384502  0.350337 -0.484532 -1.885139
# 2020-01-09  0.125384  0.291343  0.526197  2.446850  0.099972
# 2020-01-10 -1.497373 -0.045957 -0.666002  0.765761  0.348867

# %%
df["col1"]
# Out:
# 2020-01-01    0.717763
# 2020-01-02   -0.943662
# 2020-01-03    1.427493
# 2020-01-04   -1.387690
# 2020-01-05    0.138568
# 2020-01-06   -0.273605
# 2020-01-07   -1.172133
# 2020-01-08   -0.781139
# 2020-01-09    0.125384
# 2020-01-10   -1.497373
# Freq: D, Name: col1, dtype: float64

# %%
df[["col1","col2"]]
# Out:
#                 col1      col2
# 2020-01-01  0.717763 -0.063574
# 2020-01-02 -0.943662 -0.410812
# 2020-01-03  1.427493  1.391120
# 2020-01-04 -1.387690 -1.103715
# 2020-01-05  0.138568  0.448661
# 2020-01-06 -0.273605  0.237992
# 2020-01-07 -1.172133 -1.040343
# 2020-01-08 -0.781139 -1.384502
# 2020-01-09  0.125384  0.291343
# 2020-01-10 -1.497373 -0.045957

# %%
column1 = df["col1"]
column1[time_series[3]]
# Out:
# -1.3876899904898206

# %%
data1 = pd.DataFrame({'x': [1,2,3], 'y':[4,5,6]})
data1
# Out:
#    x  y
# 0  1  4
# 1  2  5
# 2  3  6

# %%
data1.loc[1] = {'x': 5, 'y': 10}

# %%
data1.loc[1]
# Out:
# x     5
# y    10
# Name: 1, dtype: int64

# %%
data1
# Out:
#    x   y
# 0  1   4
# 1  5  10
# 2  3   6

# %%
df[df["col1"]>0]
# Out:
#                 col1      col2      col3      col4      col5
# 2020-01-01  0.717763 -0.063574 -0.573939  0.371611  0.799530
# 2020-01-03  1.427493  1.391120 -0.330402  0.990232  1.304601
# 2020-01-05  0.138568  0.448661 -0.979584 -0.104487  0.349249
# 2020-01-09  0.125384  0.291343  0.526197  2.446850  0.099972

# %%
df[(df["col1"]>0) & (df["col2"]<0)][["col3","col4"]]
# Out:
#                 col3      col4
# 2020-01-01 -0.573939  0.371611

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=735df63f-eaf2-46ab-a8a5-7617b63b3308' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
